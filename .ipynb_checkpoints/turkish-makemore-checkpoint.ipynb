# %%
import pandas as pd
N = pd.read_excel("turkishfemalenames.xlsx")

# %%
print(N.type())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(N.type())
#
# File ~/Documents/projects/demirbasaf.ai/.venv/lib/python3.13/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'type'
